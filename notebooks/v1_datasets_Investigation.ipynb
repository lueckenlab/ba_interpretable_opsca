# %%
import pandas as pd
import scanpy as sc
from utils.io import read_anndata
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path
from dask import array as da
from tqdm.dask import TqdmCallback

from utils.io import read_anndata

zebrafish_adata = read_anndata(
    '/Volumes/Extreme SSD/BA_datasets/Wagner2018.h5ad',
    # X='X',
    obs='obs',
    var='var',
    obsm='obsm',
)

cengen_adata = read_anndata(
    '/Volumes/Extreme SSD/BA_datasets/Hammarlund2018.h5ad',
    # X='X',
    obs='obs',
    var='var',
    obsm='obsm',
)

pancreas_adata = read_anndata(
    '/Volumes/Extreme SSD/BA_datasets/pancreas_Luecken2021.h5ad',
    # X='X',
    obs='obs',
    var='var',
    obsm='obsm',
)

immune_adata = read_anndata(
    '/Volumes/Extreme SSD/BA_datasets/immune_Luecken2021.h5ad',
    # X='X',
    obs='obs',
    var='var',
    obsm='obsm',
)
# Out:
# dask: False, backed: False
# Read slot "obs", store as "obs"...
# Read slot "var", store as "var"...
# Read slot "obsm", store as "obsm"...
# dask: False, backed: False
# Read slot "obs", store as "obs"...
# Read slot "var", store as "var"...
# Read slot "obsm", store as "obsm"...
# dask: False, backed: False
# Read slot "obs", store as "obs"...
# Read slot "var", store as "var"...
# Read slot "obsm", store as "obsm"...
# dask: False, backed: False
# Read slot "obs", store as "obs"...
# Read slot "var", store as "var"...
# Read slot "obsm", store as "obsm"...

# %%
# checking since zebrafish dataset on Open Problems doesn't match with the description
# zebrafish_og_adata = read_anndata(
#     '/Users/seohyon/Downloads/WagnerScience2018.h5ad',
#     fail_on_missing=False  # optional, but safer
# )

zebrafish_og_adata = sc.read_h5ad('/Volumes/Extreme SSD/BA_datasets/WagnerScience2018.h5ad')

# %%
zebrafish_og_adata # what are you omg
# Out:
# AnnData object with n_obs × n_vars = 63530 × 30677
#     obs: 'n_counts', 'unique_cell_id', 'cell_names', 'library_id', 'batch', 'ClusterID', 'ClusterName', 'TissueID', 'TissueName', 'TimeID'

# %%
print(zebrafish_adata)
print(cengen_adata)
# Out:
# AnnData object with n_obs × n_vars = 26022 × 25258
#     obs: 'lab', 'sample_label', 'hpf', 'cell_type', 'labels', 'is_train', 'n_counts', 'batch', 'size_factors'
#     var: 'n_cells', 'feature_name', 'hvg', 'hvg_score'
#     obsm: 'X_pca'
# AnnData object with n_obs × n_vars = 100955 × 22469
#     obs: 'dropbox_id', 'counts', 'experiment_code', 'cell_type', 'tissue', 'n_counts', 'batch', 'size_factors'
#     var: 'n_cells', 'feature_name', 'hvg', 'hvg_score'
#     obsm: 'X_pca'

# %%
print(pancreas_adata)
print(immune_adata)
# Out:
# AnnData object with n_obs × n_vars = 16382 × 18771
#     obs: 'tech', 'celltype', 'size_factors', 'n_counts', 'cell_type', 'batch'
#     var: 'n_cells', 'feature_name', 'hvg', 'hvg_score'
#     obsm: 'X_pca'
# AnnData object with n_obs × n_vars = 33506 × 12303
#     obs: 'batch', 'chemistry', 'data_type', 'dpt_pseudotime', 'final_annotation', 'mt_frac', 'n_counts', 'n_genes', 'sample_ID', 'size_factors', 'species', 'study', 'tissue', 'cell_type'
#     var: 'n_cells', 'feature_name', 'hvg', 'hvg_score'
#     obsm: 'X_pca'

# %%
# zebrafish_adata.obs["tissue"].nunique() - no tissue obs
cengen_adata.obs["tissue"].nunique()
# Out:
# 11

# %%
# print(pancreas_adata.obs["tissue"].nunique()) -  no tissue obs
print(immune_adata.obs["tissue"].nunique())
# Out:
# 2

# %%
print(zebrafish_adata.obs["cell_type"].nunique())
print(cengen_adata.obs["cell_type"].nunique())
# Out:
# 24
# 169

# %%
print(pancreas_adata.obs["celltype"].nunique())
print(immune_adata.obs["final_annotation"].nunique()) # obs_cell_type: final_annotation
# Out:
# 14
# 16

# %%
print(zebrafish_adata.obs["batch"].nunique())
print(cengen_adata.obs["batch"].nunique())
# Out:
# 2
# 17

# %%
print(pancreas_adata.obs["tech"].nunique()) #batch = "tech"
print(immune_adata.obs["batch"].nunique())
# Out:
# 9
# 10

# %%
print(zebrafish_adata.obs["sample_label"].nunique())
print(cengen_adata.obs["experiment_code"].nunique())
# Out:
# 60
# 17

# %%
# print(pancreas_adata.obs["sample_label"].nunique()) - no sample obs
print(immune_adata.obs["sample_ID"].nunique())
# Out:
# 5

# %%
# checking if open problems zebrafish data is coherent with the original

labels = zebrafish_adata.obs["sample_label"].unique()

any(label.startswith("GSM") for label in labels)

labels
# Out:
# ['ZF30-DS5', 'ZF30-DS5b', 'ZF3S-DS5', 'ZF50-DS2', 'ZF50-DS3', ..., 'SRR6890872_24hpf', 'SRR6890873_24hpf', 'SRR6890874_24hpf', 'SRR6890875_24hpf', 'SRR6890876_24hpf']
# Length: 60
# Categories (60, object): ['SRR6890845_04hpf', 'SRR6890846_04hpf', 'SRR6890847_06hpf', 'SRR6890848_06hpf', ..., 'ZFHIGH-DS5b', 'ZFOBLONG-DS5', 'ZFOBLONG-DS5b', 'ZFS-DS5']

# %%
print(zebrafish_adata.obs["lab"].nunique()) # apparently this is used as batch
# Out:
# 2

# %%
zebrafish_adata.obs[["lab", "sample_label"]].drop_duplicates().value_counts("lab")
# Out:
# lab
# Klein     32
# Schier    28
# Name: count, dtype: int64

# %%
zebrafish_adata.obs[["lab", "sample_label"]].drop_duplicates().value_counts("sample_label")
# Out:
# sample_label
# SRR6890845_04hpf    1
# SRR6890846_04hpf    1
# SRR6890847_06hpf    1
# SRR6890848_06hpf    1
# SRR6890849_06hpf    1
# SRR6890850_06hpf    1
# SRR6890851_08hpf    1
# SRR6890852_08hpf    1
# SRR6890853_08hpf    1
# SRR6890854_08hpf    1
# SRR6890855_10hpf    1
# SRR6890856_10hpf    1
# SRR6890857_10hpf    1
# SRR6890858_10hpf    1
# SRR6890859_14hpf    1
# SRR6890860_14hpf    1
# SRR6890861_14hpf    1
# SRR6890862_14hpf    1
# SRR6890863_18hpf    1
# SRR6890864_18hpf    1
# SRR6890865_18hpf    1
# SRR6890866_18hpf    1
# SRR6890867_18hpf    1
# SRR6890868_18hpf    1
# SRR6890869_18hpf    1
# SRR6890870_24hpf    1
# SRR6890871_24hpf    1
# SRR6890872_24hpf    1
# SRR6890873_24hpf    1
# SRR6890874_24hpf    1
# SRR6890875_24hpf    1
# SRR6890876_24hpf    1
# ZF3S-DS5            1
# ZF6S-DS5            1
# ZF6S-DS5b           1
# ZF30-DS5            1
# ZF30-DS5b           1
# ZF50-DS2            1
# ZF50-DS3            1
# ZF50-DS4            1
# ZF50-DS4b           1
# ...

# %%
cengen_adata.obs[["batch", "experiment_code"]].drop_duplicates().value_counts("batch")
# Out:
# batch
# Pan-1           1
# Pan-2           1
# acr-2           1
# ceh-28_dat-1    1
# ceh-34          1
# cho-1_1         1
# cho-1_2         1
# eat-4           1
# ift-20          1
# nlp-13_ceh-2    1
# nmr-1           1
# tph-1_ceh-10    1
# unc-3           1
# unc-47_1        1
# unc-47_2        1
# unc-53          1
# unc-86          1
# Name: count, dtype: int64

# %%
cengen_adata.obs[["batch", "experiment_code"]].drop_duplicates().value_counts("experiment_code")
# Out:
# experiment_code
# Pan-1           1
# Pan-2           1
# acr-2           1
# ceh-28_dat-1    1
# ceh-34          1
# cho-1_1         1
# cho-1_2         1
# eat-4           1
# ift-20          1
# nlp-13_ceh-2    1
# nmr-1           1
# tph-1_ceh-10    1
# unc-3           1
# unc-47_1        1
# unc-47_2        1
# unc-53          1
# unc-86          1
# Name: count, dtype: int64

# %%
immune_adata.obs[["batch", "sample_ID"]].drop_duplicates().value_counts("batch")
# Out:
# batch
# 10X               1
# Freytag           1
# Oetjen_A          1
# Oetjen_P          1
# Oetjen_U          1
# Sun_sample1_CS    1
# Sun_sample2_KC    1
# Sun_sample3_TB    1
# Sun_sample4_TC    1
# Villani           1
# Name: count, dtype: int64

# %%
immune_adata.obs[["batch", "sample_ID"]].drop_duplicates().value_counts("sample_ID")
# Out:
# sample_ID
# 3    4
# 0    3
# 1    1
# 2    1
# 4    1
# Name: count, dtype: int64

# %%
batch_size = zebrafish_adata.obs["batch"].value_counts().sort_values(ascending=False)
mean = np.mean(batch_size)
std = np.std(batch_size)
min_val = batch_size.min()
max_val = batch_size.max()
print(f"Mean batch size: {mean:.2f}")
print(f"Standard deviation: {std:.2f}")
print(f"Minimum batch size: {min_val}")
print(f"Maximum batch size: {max_val}")
print(f"Coefficient of variance: {std/mean:.2f}")
# Out:
# Mean batch size: 13011.00
# Standard deviation: 2403.00
# Minimum batch size: 10608
# Maximum batch size: 15414
# Coefficient of variance: 0.18

# %%
batch_size = cengen_adata.obs["batch"].value_counts().sort_values(ascending=False)
mean = np.mean(batch_size)
std = np.std(batch_size)
min_val = batch_size.min()
max_val = batch_size.max()
print(f"Mean batch size: {mean:.2f}")
print(f"Standard deviation: {std:.2f}")
print(f"Minimum batch size: {min_val}")
print(f"Maximum batch size: {max_val}")
print(f"Coefficient of variance: {std/mean:.2f}")
# Out:
# Mean batch size: 5938.53
# Standard deviation: 3067.44
# Minimum batch size: 1669
# Maximum batch size: 13139
# Coefficient of variance: 0.52

# %%
batch_size = pancreas_adata.obs["tech"].value_counts().sort_values(ascending=False)
mean = np.mean(batch_size)
std = np.std(batch_size)
min_val = batch_size.min()
max_val = batch_size.max()
print(f"Mean batch size: {mean:.2f}")
print(f"Standard deviation: {std:.2f}")
print(f"Minimum batch size: {min_val}")
print(f"Maximum batch size: {max_val}")
print(f"Coefficient of variance: {std/mean:.2f}")
# Out:
# Mean batch size: 1820.22
# Standard deviation: 829.50
# Minimum batch size: 638
# Maximum batch size: 3605
# Coefficient of variance: 0.46

# %%
batch_size = immune_adata.obs["batch"].value_counts().sort_values(ascending=False)
mean = np.mean(batch_size)
std = np.std(batch_size)
min_val = batch_size.min()
max_val = batch_size.max()
print(f"Mean batch size: {mean:.2f}")
print(f"Standard deviation: {std:.2f}")
print(f"Minimum batch size: {min_val}")
print(f"Maximum batch size: {max_val}")
print(f"Coefficient of variance: {std/mean:.2f}")
# Out:
# Mean batch size: 3350.60
# Standard deviation: 2571.38
# Minimum batch size: 1022
# Maximum batch size: 10727
# Coefficient of variance: 0.77
